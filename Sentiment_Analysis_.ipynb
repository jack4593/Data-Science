# %% [markdown]
# The aim of this little project was to look at the tweets of various political figures and track their sentiment across time

# %%
#import the packages...
import tweepy
from  textblob import TextBlob
from  wordcloud import WordCloud
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
from pylab import *
plt.style.use('fivethirtyeight')
print('Imports complete')
# Out:
# Imports complete

# %%
#Get the Data 
log = pd.read_csv('Login.csv')
print('Import complete')
# Out:
# Import complete

# %%
#Twitter API Credentials 
consumerKey = log['Key'][0]
consumersecret = log['Key'][1]
brearer_token = log['Key'][2]
accesstoken = log['Key'][3]
accesstokensecret = log['Key'][4]

# %%
#authentication object creation
authenticate = tweepy.OAuthHandler(consumerKey, consumersecret)
# Set Access Token Secret 

authenticate.set_access_token(accesstoken, accesstokensecret)

# API Object while passing authentication infromation 
api = tweepy.API(authenticate, wait_on_rate_limit=True)

# %%
# Extract 100 Tweets from User
posts = api.user_timeline(screen_name='BorisJohnson', count = 1000, lang = 'eng', tweet_mode = 'extended')

# %%
#print last 5 tweets from accoutn 
print ("Show 5 recent tweets")
for tweet in posts [0:5]:
  print (tweet.full_text +'/n')
# Out:
# Show 5 recent tweets
# Marching for Pride in 1972 was an incredibly brave thing to do.
#
# Today will see friends and families once more coming together to mark the tremendous milestone of 50 years of our capital’s Pride.
#
# Happy #Pride! https://t.co/YiCzEf4mmG/n
# Though they may be one of our most distant allies, the UK counts New Zealand among our closest partners.
#
# Fantastic to welcome @jacindaardern to Downing Street today as we take this alliance of old friends forward and meet the challenges and opportunities of the future 🇬🇧🇳🇿 https://t.co/cajzxk6zI4/n
# Strengthening security.
#
# Defending democracy.
#
# Supporting Ukraine.
#
# @NATO stands united. https://t.co/KT2gAdEJB8/n
# 25 years ago we made a promise to the people of Hong Kong.
#
# We intend to keep it. https://t.co/nIN96ZydgV/n
# Great news: in less than six months we’ve supported half a million people into work.
#
# Helping people find the security of a stable income, through a job they can take pride in, is one of the best ways for people support their families during these challenging times. https://t.co/uaeeE77Phy/n

# %%
df = pd.DataFrame([tweet.full_text for tweet in posts], columns = ['Tweets'])

df.head()
# Out:
#                                               Tweets
# 0  Marching for Pride in 1972 was an incredibly b...
# 1  Though they may be one of our most distant all...
# 2  Strengthening security. \n\nDefending democrac...
# 3  25 years ago we made a promise to the people o...
# 4  Great news: in less than six months we’ve supp...

# %%
#clean the text 

#create a function to clean the data
def CleanText(text):
  text = re.sub(r'@[A-Za-z0-9]+','',text) #Removed @mentions
  text = re.sub(r'#', '', text)# remove hashtags
  text = re.sub(r'RT[[\s]+','', text) # remove RT
  text = re.sub(r'https?:\/\/\S+','', text)# remove hyper links
  return text

# %%
#apply the cleaning function
df['Tweets'] = df['Tweets'].apply(CleanText)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: FutureWarning: Possible nested set at position 3
#   import sys

# %%
#plot a word cluoud
allWords = ' '.join([twts for twts in df['Tweets']])
wordCloud = WordCloud (width=500, height = 300, random_state = 20, background_color='white', max_font_size =119).generate(allWords)
#create the word cloud
plt.imshow(wordCloud, interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %%
# create function to get subjectivity on
def getSubjectivity  (text):
  return TextBlob(text).sentiment.subjectivity

# function to get polarity pos or neg?
def getPolarity(text):
  return TextBlob(text).sentiment.polarity

#create columns 
df['Subjectivity'] = df['Tweets'].apply(getSubjectivity)
df['Polarity'] = df['Tweets'].apply(getPolarity)

df
# Out:
#                                                 Tweets  Subjectivity  Polarity
# 0    Marching for Pride in 1972 was an incredibly b...      0.875000  0.658333
# 1    Though they may be one of our most distant all...      0.489935  0.262338
# 2    Strengthening security. \n\nDefending democrac...      0.250000  0.250000
# 3    25 years ago we made a promise to the people o...      0.000000  0.000000
# 4    Great news: in less than six months we’ve supp...      0.456667  0.393333
# ..                                                 ...           ...       ...
# 195  Tomorrow’s elections are about who provides yo...      0.480000  0.140000
# 196  We’re investing in new nuclear power to bring ...      0.378072 -0.004588
# 197  I have one message for you today: Ukraine will...      0.600000  0.600000
# 198  This is Ukraine’s finest hour, an epic chapter...      0.483333  0.166667
# 199  It was a fantastic day to be out campaigning i...      0.650000  0.150000
#
# [200 rows x 3 columns]

# %%
#create function to compute the negative, neutral and positive analysis
def getAnalysis(score):
  if score <0:
    return 'Negative'
  elif score == 0:
    return 'Neutral'
  else:
    return 'positive'

df['Analysis'] = df['Polarity'].apply(getAnalysis)

df.head(100)
# Out:
#                                                Tweets  Subjectivity  Polarity  \
# 0   Marching for Pride in 1972 was an incredibly b...      0.875000  0.658333
# 1   Though they may be one of our most distant all...      0.489935  0.262338
# 2   Strengthening security. \n\nDefending democrac...      0.250000  0.250000
# 3   25 years ago we made a promise to the people o...      0.000000  0.000000
# 4   Great news: in less than six months we’ve supp...      0.456667  0.393333
# ..                                                ...           ...       ...
# 95  : The UK has been sanctioning Putin, his regim...      0.000000  0.000000
# 96  : Jackdaw gas field - originally licensed in 1...      0.875000  0.187500
# 97  Congratulations to the city of Bradford on bec...      0.800000  0.412500
# 98  We want to hear from more parents, teachers, p...      0.366667  0.166667
# 99  Important discussion on children’s mental heal...      0.580000  0.160000
#
#     Analysis
# 0   positive
# 1   positive
# 2   positive
# 3    Neutral
# 4   positive
# ..       ...
# 95   Neutral
# 96  positive
# 97  positive
# 98  positive
# 99  positive
#
# [100 rows x 4 columns]

# %%
j = 1
sortedDF = df.sort_values(by=['Polarity'])
for i in range (0, sortedDF.shape[0]):
  if (sortedDF['Analysis'][i] == 'positive'):
   print(str(j)+ ') '+sortedDF['Tweets'][i])
   j = j+1
   print()
# Out:
# 1) Marching for Pride in 1972 was an incredibly brave thing to do.
#
# Today will see friends and families once more coming together to mark the tremendous milestone of 50 years of our capital’s Pride.
#
# Happy Pride!
#
# 2) Though they may be one of our most distant allies, the UK counts New Zealand among our closest partners.
#
# Fantastic to welcome  to Downing Street today as we take this alliance of old friends forward and meet the challenges and opportunities of the future 🇬🇧🇳🇿
#
# 3) Strengthening security.
#
# Defending democracy.
#
# Supporting Ukraine.
#
#  stands united.
#
# 4) Great news: in less than six months we’ve supported half a million people into work.
#
# Helping people find the security of a stable income, through a job they can take pride in, is one of the best ways for people support their families during these challenging times.
#
# 5) A huge delight to meet  Magdalena Andersson and President  again.
#
# The accession of Finland and Sweden to  will permanently strengthen our defensive Alliance, helping to keep us all safe.
#
# WeAreNATO
#
# 6) Good discussions with President . I welcome Türkiye's agreement with Sweden and Finland, paving the way for their accession to .
#
# I'm grateful for the President's leadership on getting grain out of Ukraine – a crisis that's having global repercussions.
#
# 7) At this  Leaders’ Summit, I’ll be urging fellow nations to continue to do everything they can to support Ukraine.
#
# The UK has always played a historic role in the  alliance, working to address the biggest global threats and build a more secure world.
#
# 8) The G7 stands strong together.
#
# We're backing President Zelenskyy and Ukraine with the strategic resolve to turn the tide in this fight against Putin's barbarism.
#
# 9) I’m terribly saddened to hear that Dame Deborah James has died. What an inspiration she was to so many.
#
# The awareness she brought to bowel cancer and the research her campaigning has funded will be her enduring legacy.
#
# Because of her, many many lives will be saved.
#
# 10) Fantastic news as we kick off the NATO Summit.
#
# Sweden and Finland's membership will make our brilliant alliance stronger and safer.
#
# 11) My thoughts are with Helen McCourt’s loved ones today.
#
# They have still not had the closure they so deserve, but it is thanks to the campaigning and bravery of _mccourt that we have Helen’s Law.
#
#
#
# (1/2)
#
# 12) From Ukraine to the global economy and climate change it was great to talk to  earlier about the shared challenges the United Kingdom and the United States face together as friends and partners.
#
# 13) The measures we have announced today will directly hit Russian oligarchs and strike at the heart of Putin’s war machine.
#
# We need to starve the Putin regime of its funding. The UK and our allies are doing just that.
#
# 14) : The UK stands ready to guarantee a further £429 million of financial support for Ukraine.
#
# This brings the total amou…
#
# 15) Now is not the time to give up on Ukraine, they need the support and resolve of the  more than ever.
#
# The UK will continue to back Ukraine every step of the way, because we know that their security is our security, and their freedom is our freedom.
#
# 16) An inspiring and uplifting few days! From bolstering our trade networks to launching programmes to get girls around the world access to quality education – this is what  is about.
#
# We should all cherish the Commonwealth.
#
# 17) Our unique Commonwealth family is bound by our shared values and commitment to tackle today’s global challenges together.
#
# 🇦🇬🇦🇺🇧🇸🇧🇩🇧🇧🇧🇿🇧🇼🇧🇳🇨🇲🇨🇦🇨🇾🇩🇲🇸🇿🇫🇯🇬🇲🇬🇭🇬🇩🇬🇾
# 🇮🇳🇯🇲🇰🇪🇰🇮🇱🇸🇲🇼🇲🇾🇲🇻🇲🇹🇲🇺🇲🇿🇳🇦🇳🇷🇳🇿🇳🇬🇵🇰🇵🇬🇷🇼
# 🇰🇳🇱🇨🇻🇨🇼🇸🇸🇨🇸🇱🇸🇬🇸🇧🇿🇦🇱🇰🇹🇿🇹🇴🇹🇹🇹🇻🇺🇬🇬🇧🇻🇺🇿🇲
#
# 18) We’re turbocharging trade with the fast-growing economies of the Commonwealth.
#
# By striking free trade agreements and liberalising tariffs, we are powering growth &amp; prosperity, creating jobs and easing the pressures we all face on the cost of living – benefitting all our people.
#
# 19) Good to meet President  in the beautiful city of Kigali this morning.
#
# As we hand over the Commonwealth Chair-in-Office to Rwanda, our countries will be working together closely to address the most pressing global challenges.
#
# 🇬🇧🇷🇼
#
# 20) I’ve arrived in Rwanda for CHOGM to address global challenges, from hunger to climate change, and to turbocharge trade with some of the world’s most dynamic economies.
#
# With our shared values, history and language – the Commonwealth is a unique and vital association.
#
# 21) We must take defined, coordinated action for the prosperity and security of all our peoples.
#
# Over the next week I'll be meeting leaders at the ,  and  to urge unity in the face of global challenges.
#
# StandWithUkraine
#
# 22) The majority of people have already come forward for their spring booster – it’s vital that everyone eligible now takes up the offer so we can carry on protecting the most vulnerable against Covid this summer.
#
# 23) : As part of ArmedForcesWeek I welcomed a very special guest to Downing Street. Finley Skinner, 7, from Derby, has raised…
#
# 24) Today’s partnership with _tx puts us at the forefront of the research and technology needed to fight against future health threats, while creating more jobs.
#
# Our investment will bring supercharged, home-grown vaccines right to our shores.
#
# 25) A powerful and moving story about how we don't need to face bullying alone.
#
# Thank you for sharing Nadhim.
#
# SpeakOutAboutBullying
#
# 26) Huge congratulations to  on winning the .
#
# You have made the city of Sheffield and indeed the whole country incredibly proud.
#
# 27) Putin’s grand imperial design for the total reconquest of Ukraine has been derailed.
#
# There are four vital steps we must take to strengthen the hand of our Ukrainian friends and ensure we finish this war on the terms that  has laid out.
#
#
#
# 28) Thank you my friend President  for hosting me in Ukraine yesterday.
#
# It was incredibly moving to walk the streets of Kyiv with you once more, to pay tribute to your fallen soldiers whose sacrifice, unconquerable courage and bravery we will never forget.
#
# 29) Mr President, Volodymyr,
#
# It is good to be in Kyiv again.
#
# 30) I spoke to President  this evening to reiterate the UK’s full support for Ukraine until its eventual victory.
#
# The  and  summits later this month will be an opportunity to demonstrate the West’s unity and resolve to support Ukraine in the long-term.
#
# 31) Finding cancer early saves lives, and we want to make it as easy as possible to get checked.
#
# From pharmacists trained to spot the signs and refer people directly, to mobile cancer scanning trucks, we're finding new ways to get the right care to you, quickly and closer to home.
#
# 32) Forty years since British soldiers liberated Port Stanley we remember with pride all those who served and died freeing the Falkland Islands from foreign occupation.
#
# Because of them, Falkland Islanders today live and thrive in peace and freedom.
#
# Falklands40
#
# 33) We’re appointing a Cost of Living business tsar, , former CEO of .
#
# In partnership with businesses, he will develop and promote initiatives that help households and families with rising costs.
#
# Find out what support is available:
#
# 34) Today the unemployment rate remains historically low and still well below pre-pandemic levels.
#
# We’re focused on:
# - Building a high-wage, high-skill economy
# - Giving people opportunities to better support their families
# - Providing help with the cost of living
#
# 35) : 40 years ago, British Armed Forces liberated the Falkland Islands.
#
# We remember their brave sacrifice to defend the Islanders…
#
# 36) Today marks five years since the Grenfell Tower fire took the lives of 72 people.
#
# My thoughts are with the survivors, those who lost loved ones and the wider community.
#
# 37) Delighted to sign a joint declaration with Prime Minister .
#
# Our countries are old allies and friends.
#
# We’ll continue to work together closely on defence, security, trade, and more.
#
# 🇬🇧🇵🇹
#
# 38) Hi , we’re backing British farming by investing in new technology so that we grow and eat more of our fantastic homegrown produce.
#
# We’re also supporting farmers to unlock the potential of their land and seize new opportunities.
#
# 39) We're backing British farmers so we can grow and eat more of our own domestic produce, harness new tech opportunities and strengthen our food security.
#
# Introducing our first ever Food Strategy:
#
# 40) The Great Tech Revolution is transforming our world and I want the UK to be at the forefront of this advance.
#
# Looking forward to meeting many of the leaders in tech later to discuss how we are making this happen – growing the economy and boosting jobs.
#
#
#
# 41) One week on from the spectacular PlatinumJubilee weekend I'd like to thank all those who helped make the celebrations happen.
#
# A huge team effort. Well done to all!
#
# 42) Russia’s barbaric invasion of Ukraine has only highlighted the critical importance of the  to world security.
#
# We need bold, definitive action to respond to major challenges.
#
# This is the message I will be taking to Bavaria this summer.
#
# 43) I had a fantastic day out at the  show, meeting our incredible farmers and rural communities that produce the best food and drink in the world.
#
# 44) The UK and the US are the greatest of allies and closest of partners.
#
# I look forward to continuing our cooperation on the world’s most important issues.
#
# 45) I’m proud of what 🇬🇧 and 🇺🇸 have achieved since agreeing our new Atlantic Charter.
#
# Together we've:
# ▪️ Pioneered better pandemic preparedness
# ▪️ Stepped up action on climate change &amp; energy security
# ▪️ Boosted trade links
# ▪️ Defended democracy
# ▪️ Strengthened security
#
# 46) Home ownership is what overwhelmingly, people in this country want.
#
# It’s good for society, great for the economy, it drives jobs and growth – that’s why we’re supporting it.
#
# 47) : Local authorities and schools are doing a phenomenal job of supporting Ukrainian children back into education 🇬🇧🇺🇦
#
# Today…
#
# 48) Nobody should be locked out of home ownership because of where they live or when they were born.
#
# Today we've set out our plans to better support more people across the UK to buy a home.
#
# 49) We're tackling the rising cost of housing.
#
# By extending the right-to-buy scheme to housing associations, a further 2.5 million households will be eligible to purchase their own home.
#
# We're reviewing access to mortgages so those in 'Generation Rent' can become 'Generation Buy'.
#
# 50) : Two weeks ago we announced new cost of living support measures.
#
# Now, a single mother on universal credit, working full-ti…
#
# 51) This CarersWeek, I want to thank the millions of carers across the UK for all they do to support their loved ones.
#
# 52) We want NHS patients to be able to access potentially lifesaving or life-prolonging medicines more quickly.
#
# Our £340 million Innovative Medicines Fund will support patients with any condition to get early access to the most clinically promising treatments.
#
# 53) This is a government that delivers on what the people of this country care about most.
#
# We are focused on uniting and levelling up across the country and unleashing the potential of the whole United Kingdom.
#
# 54) We need to come together as a party and focus on what this government is doing to help people with the cost of living, to clear the COVID backlogs and to make our streets safer.
#
# We will continue to unite, level up and strengthen our economy.
#
# 55) President  just updated me on the ongoing battle against Russian aggression in the Donbas.
#
# It's clear the Ukrainian people will not bow to Russian brutality. We're unwavering in our mission of ensuring Ukraine is defended and supported for the long-term.
#
# 56) Congratulations to  and the rest of the  squad in qualifying for the FIFA World Cup in Qatar.
#
# Brilliant to see two UK nations in the competition.
#
# Da iawn Cymru!
#
# 113) Sharing more intelligence, bolstering military exercises and jointly developing technology, I am very pleased to sign a mutual security assurance declaration with  Magdalena Andersson.
#
# We face a new reality. But we face it together.
#
# 🇬🇧🇸🇪
#
# 114) Thinking of the people of Manchester and those marking the opening of the Glade of Light memorial today.
#
# It will stand for years to come as a space to commemorate the lives tragically lost in the cowardly terrorist attack at Manchester Arena.
#
# We will always remember them.
#
# 115) : Thank you for sharing your priorities with me.
#
# In these challenging times, this government will provide the leadership n…
#
# 116) Thank you for sharing your priorities with me.
#
# In these challenging times, this government will provide the leadership needed to deliver for you.
#
# Your priorities are our priorities and we are focused like a laser on the issues that matter to you most.
#
# QueensSpeech
#
# 117) : The Prime Minister hosted the No10SpringShowcase at Downing Street today to fly the flag for British food, goods &amp; ex…
#
# 118) I have never been more certain that Ukraine will win.
#
# Britain will stand shoulder-to-shoulder with Ukraine for as long as it takes.
#
# Slava Ukraini 🇺🇦
#
# 119) This afternoon I spoke to G7 and European leaders, as well as .
#
# We agreed to intensify our economic and military support for Ukraine.
#
# We also agreed more must be done to underpin food security and ensure agricultural exports can leave the country.
#
# 120) : Congratulations to all those newly elected in Northern Ireland.
#
# It is crucial that the party leaders now come together…
#
# 121) I joined an art class at Field End Infant School in my constituency as they get ready to celebrate the Queen’s Platinum Jubilee.
#
# The teachers are doing a fantastic job to help children recover from the pandemic as part of the National Tutoring Programme.
#
# 122) I was honoured to speak at the Brave Ukraine Fundraiser this evening alongside .
#
# Our support for Ukraine is unwavering, and we must do everything we can to help Ukraine defend itself and ease the burden of suffering on innocent Ukrainians.
#
# Slava Ukraini 🇺🇦
#
# 123) Delighted to announce this special Queen’s Platinum Jubilee Volunteering Award. Looking forward to celebrating 20 incredible charities and their outstanding work with young people.
#
# 124) Fantastic to host Prime Minister  as we agree to strengthen our cooperation on:
#
# ✅  Defence
# ✅  Green Energy
# ✅  Trade and Exports
#
# This will deliver growth and security for both our nations for years to come.
#
# 125) Welcome to Downing Street Prime Minister .
#
#  首相を首相官邸にお迎え出来て光栄です。
#
# 🇬🇧 🇯🇵
#
# 126) For better services and lower council tax, get out and vote  today.
#
# 127) Wishing Israel and my friends _Herzog and  a very happy Independence Day.
#
# The UK has always stood by Israel and its right to live as any nation should be able to – in peace, prosperity and security 🇬🇧🇮🇱
#
# 128) Vote  today for lower council tax and better local services.
#
# 129) Fantastic news that Airbus are further investing in Broughton in North Wales, bringing high-quality jobs, boosting growth and driving the Welsh economy forward.
#
# 130) : ⚠️ Lib Dems = higher council tax.
#
# ⚠️ None of the cheapest 50 councils in England are run by Lib Dems.
#
# VoteConservativ…
#
# 131) Many congratulations to all the staff and students at Uxbridge College in my constituency on their recent Ofsted report.
#
# The college is an important part of the local community and plays a vital role in training up the workforce of the future.
#
# 132) I’m proud to have secured the investment for Crossrail over a decade ago, and thrilled the Elizabeth line will soon spring into action &amp; transform journeys for millions of people.
#
# Long-term investment pays off, and we’re continuing to invest in big projects right across the UK.
#
# 133) : Tomorrow, your choice is clear.
#
# Conservative councils who deliver better local services and the lowest council tax or L…
#
# 134) Conservative councillors deliver better local services for lower council taxes.
#
# Vote  tomorrow.
#
# 135) Tomorrow’s elections are about who provides your crucial local services, with Hillingdon residents enjoying free garden and food waste collections alongside their weekly rubbish and recycling collections.
#
# Vote  tomorrow.
#
# 136) I have one message for you today: Ukraine will win. Ukraine will be free.
#
# 137) This is Ukraine’s finest hour, an epic chapter in your national story.
#
# Your children and grandchildren will say that Ukrainians taught the world that the brute force of an aggressor counts for nothing against the moral force of a people determined to be free.
#
# 138) It was a fantastic day to be out campaigning in the North East, where we’re delivering a massive programme of investment as part of our plan to level up the whole of the UK.
#
# Remember to vote  this Thursday for Conservative councillors who keep your council tax low.

# %%
#print the negative tweets

j = 1
sortedDF = df.sort_values(by=['Polarity'], ascending = 'False')
for i in range (0, sortedDF.shape[0]):
  if (sortedDF['Analysis'][i] == 'Negative'):
   print(str(j)+ ') '+sortedDF['Tweets'][i])
   j = j+1
   print()
# Out:
# 1) The UK is leading the way in providing vital military assistance to Ukraine.
#
# We continue to stand squarely behind President  and the Ukrainian people to ensure Putin fails 🇬🇧🇺🇦
#
# 2) This lasting legacy will help other families to avoid the pain of having their grief compounded by offenders who cruelly refuse to disclose information about their victims.
#
# (2/2)
#
# 3) This Government is making our streets safer by ensuring those guilty of heinous crimes get the punishments they deserve and spend longer behind bars to protect the public.
#
# 4) Putin’s actions in Ukraine are creating terrible aftershocks, driving up energy and food prices across the world.
#
# Global leaders need to come together to help Ukraine and make life easier for households across the world.
#
# Nothing should be off the table.
#
# 5) We wanted to pay a special tribute to  as he sadly couldn’t be with us in person at the  ⤵️
#
# 6) We must support Ukraine to strengthen their hand in both the war and any future negotiations.
#
# President  and I agreed to step up our military support for Ukraine at this critical moment, and to enhance Anglo-French cooperation on defence and security.
#
# 🇬🇧🇫🇷
#
# 7) Global prosperity and stability is being threatened – with Commonwealth countries bearing the brunt of Putin’s folly in Ukraine.
#
# Together we can bring food prices down and get the world economy back on track, as we stand up for the freedoms we all believe in.
#
# 8) The strikes today are wrong and unnecessary.
#
# 9) We shall not forget the thousands of men, women and children who are being killed every day in Putin’s war of aggression.
#
# The UK will work tirelessly with our allies to bring enduring peace to the people of Ukraine.
#
# 10) Remembering Jo Cox and her contribution to politics and public life. My thoughts are with her loved ones today.
#
# We will never let those who commit evil and despicable acts to triumph over democracy.
#
# 11) : Just Announced: I have sanctioned:
#
# 👉 Patriarch Kirill, Head of Russian Orthodox Church &amp; vocal supporter of Putin’s war
#
# 👉 E…
#
# 12) : Thank you Len ⬇️
# Don’t be shy, pls Apply!
# PensionCredit ✅👍
#
# 13) Putin's instinct is always to silence dissent &amp; suppress those who accurately report his disastrous campaign in Ukraine.
#
# I stand fully behind the British media and my colleagues in government and parliament &amp; will continue to support their tireless work.
#
#
#
# 14) We will back Britain and we will back the British people for as long as it takes.
#
# 15) Welcome news from the High Court today.
#
# We cannot allow people traffickers to put lives at risk and our world leading partnership will help break the business model of these ruthless criminals.
#
# 16) Remembering all those affected by the horrific attack at London Bridge five years ago. My heart goes out to the victims and their families.
#
# The indomitable spirit shown by Londoners that night and in the following weeks showed this city will never be cowed in the face of terror.
#
# 17) All households will get £400 off their October energy bills and the 8m most vulnerable households will get at least £1,200 of support to help with the cost of living this year.
#
# A temporary Energy Profits Levy will help pay for this support and promote investment in our economy.
#
# 18) Thank you to schools up and down the country for welcoming Ukrainian children into their classrooms as they flee the devastating war in Ukraine.
#
# 19) My thoughts are with the victims, families and friends of all those affected by the cowardly attack on Manchester Arena five years ago today.
#
# The bravery and defiance shown so courageously by Mancunians in the days that followed shows hatred will never win.
#
# 20) I updated the President on support flowing to Ukraine’s defence, including long-range artillery, shore-to-ship missiles and unmanned drones.
#
# This is part of our additional £1.3 billion military aid package for Ukraine. 2/4
#
# 21) This is an historic day for our alliance &amp; the world. Not long ago nobody would have predicted this step, but Putin’s appalling ambitions have transformed the geopolitical contours of our continent.
#
# I look forward to welcoming Finland &amp; Sweden into the  family very soon.
#
# 22) The signing of new security declarations with Sweden and Finland is a symbol of the everlasting assurance between our nations.
#
# They are a long term assurance to bolster military ties and global stability, and fortify Europe’s defences for generations to come.
#
# 🇬🇧🇸🇪🇫🇮
#
# 23) : On VEDay77 we thank our armed forces for their service &amp; sacrifice. As Russia’s illegal war in Ukraine has shattere…
#
# 24) On VE Day, as we remember those who sacrificed their lives in WW2, we also think of those who've died and suffered in Russia’s illegal invasion of Ukraine.
#
# Our respect for those who fought strengthens our determination to support Ukrainians today.
#
# WeStandWithUkraine
#
# 25) I’d like to thank all those who voted in todays local elections, and to  supporters and  activists across the country for their hard work to support our plan to keep council taxes low.
#
# 26) I spoke to President  and thanked him for the opportunity to address Ukrainian parliamentarians striving to uphold democracy and freedom earlier this week.
#
# We will offer further military and humanitarian support to Ukraine. This conflict is about right versus wrong.
#
# 27) We’re investing in new nuclear power to bring clean, green and reliable energy to the UK, reduce our dependence on foreign fossil fuels and bring down energy bills for the long term.

# %%
#plot the polarity and subjectivity 
plt.figure(figsize=(8,6))

for i in range (0, df.shape[0]):
  plt.scatter(df['Polarity'][i], df['Subjectivity'][i], color = 'Blue')

plt.title('Sentiment Analysis')
plt.xlabel('Polarity')
plt.ylabel('Subjectivity')
# Out:
# Text(0, 0.5, 'Subjectivity')

# %%
#get the % of positive tweets 
ptweets = df[df.Analysis == 'positive']
ptweets = ptweets['Tweets']

posper = round( (ptweets.shape[0])/df.shape[0]*100,1)
posper
#print("% of Positive Tweets is" + posper)
# Out:
# 69.0

# %%
#get the % of positive tweets 
ptweets = df[df.Analysis == 'Negative']
ptweets = ptweets['Tweets']

negper = round( (ptweets.shape[0])/df.shape[0]*100,1)
negper
# Out:
# 13.5

# %%
df['Analysis'].value_counts()
plt.title('Sentiment Analysis')
plt.xlabel('Sentiment')
plt.ylabel('Counts')
df.Analysis.value_counts().plot(kind='bar')
plt.show()
